# %%
from goose3 import Goose

# %%
from readability import Document

# %%
import requests

# %%
# determine the number of times that common twitter reference phrases appear

twitter_phrases = ['tweeted', 'to twitter', 'tweets', 'tweeting', 'retweet', 'in a tweet', 'to tweet', 'tweet from', 
                  'wrote on twitter', 'said on twitter']


def count_twitter_phrases(article_text):
    twitter_phrase_count = 0
    # find the first occurence of the twitter phrase, then continue searching for the 
    # next occurence of the twitter phrase from the index of end of the current twitter phrase
    # instance until there are no more twitter phrases located 
    for twitter_phrase in twitter_phrases:
        start_index = 0
        phrase_index = 0
        while (phrase_index != -1):
            phrase_index = article_text.find(twitter_phrase, start_index)
            start_index = phrase_index + len(twitter_phrase)
            if phrase_index != -1:
                twitter_phrase_count += 1
    return twitter_phrase_count

# %%
from html.parser import HTMLParser

class MyHTMLParser(HTMLParser):
    
    def __init__(self):
        self.tweet_embed_count = 0
        self.twitter_phrase_count = 0
        HTMLParser.__init__(self)
    
    
    def handle_starttag(self, tag, attrs):
        # check for anchor tags 
        if tag == 'a':
            # check if href is defined in the anchor tag
            for name, value in attrs:
                if name == 'href':
                    # check if twitter.com is in the href url
                    if 'twitter.com' in value:
                        self.tweet_embed_count += 1

# %%
import json
def count_tweets_json(story_id):
    with open('stories/' + str(story_id) + '.json') as f:
        article_json = json.load(f)
    html_parser = MyHTMLParser()
    article_full_text = article_json['story_text']
    article_html = article_json['raw_first_download_file']
    article_text = Document(article_html)
    html_parser.feed(article_text.summary())
    tweet_embed_count = html_parser.tweet_embed_count
    return (count_twitter_phrases(article_full_text), tweet_embed_count)

# %%
def count_tweet_embed_json(story_id):
    return (count_tweets_json(story_id))[0]

# %%
def count_tweet_refs_json(story_id):
    return (count_tweets_json(story_id))[1]

# %%
import pandas as pd
# import csv file with the urls for each article with labeled amount of tweets per article 
# into a dataframe

story_csv_url = 'tweet_story_ids.csv'
story_df = pd.read_csv(story_csv_url)

# %%
def generate_tweet_counts_json(article_df):
    article_df['tweet_mentions'] = article_df.apply(lambda row: count_tweet_refs_json(row['stories_id']), axis = 1)
    article_df['tweet_embeds'] = article_df.apply(lambda row: count_tweet_embed_json(row['stories_id']), axis = 1)
    article_df['goose3_tweet_embeds'] = article_df.apply(lambda row: count_tweets_goose(row['url']), axis = 1)
    
    return article_df

# %%
generate_tweet_counts_json(story_df)
# Out:
#      Unnamed: 0  stories_id  \
# 0             0  1948372128
# 1             1  1880746751
# 2             2  1872948216
# 3             3  1822028130
# 4             4  1863258802
# ..          ...         ...
# 96           96  1845803266
# 97           97  1817680913
# 98           98  1842855441
# 99           99  1839643569
# 100         100  1888884815
#
#                                                  title  \
# 0    Neil Gaiman calls out fans complaining about S...
# 1    Brazilian politician's cunning plan to fight C...
# 2    Royal Family Missed 'Greatest Opportunity for ...
# 3    Virtual memorial for late Phoenix civil rights...
# 4    Labor Groups And Progressives Urge Biden To Su...
# ..                                                 ...
# 96             Earnings Scheduled For February 8, 2021
# 97   US Capitol unrest leads to Steve Kerr's condem...
# 98   Santa Anita horse racing consensus picks for F...
# 99   The 'Cloffice' Is the New Cubicle: Expert Insp...
# 100  3 Takeaways From the Avalanche’s 5-1 Win Over ...
#
#                                                    url  tweet_embeds  \
# 0    https://www.monstersandcritics.com/tv/neil-gai...             1
# 1    https://www.theguardian.com/world/2021/mar/16/...             1
# 2    https://www.newsweek.com/royal-family-missed-g...             2
# 3    http://rssfeeds.azcentral.com/~/641472518/0/ph...             1
# 4    https://www.huffpost.com/entry/labor-groups-an...             1
# ..                                                 ...           ...
# 96   http://feeds.benzinga.com/~r/benzinga/~3/NLo--...             0
# 97        https://upstract.com/p/yrtxefw3?ref=rss&rd=1             0
# 98   https://www.ocregister.com/2021/02/04/santa-an...             0
# 99   https://www.sfgate.com/realestate/article/The-...             0
# 100  https://www.yardbarker.com/nhl/articles/3_take...             0
#
#      tweet_mentions  goose3_tweet_embeds
# 0                 1                    0
# 1                 0                    0
# 2                 0                    1
# 3                 2                    0
# 4                 1                    0
# ..              ...                  ...
# 96                0                    0
# 97                0                    0
# 98                0                    0
# 99                0                    0
# 100               0                    0
#
# [101 rows x 7 columns]

# %%
# return the total 'twitter occurences'
def count_tweets(article_url):
    r = requests.get(article_url) 
    article_full_text = (r.text).lower()
    article_text = Document(article_full_text)
    html_parser = MyHTMLParser()
    html_parser.feed(article_text.summary())
    tweet_embed_count = html_parser.tweet_embed_count
    return (count_twitter_phrases(article_full_text), tweet_embed_count)

# %%
def count_tweets_goose(article_url):
    g = Goose()
    article = g.extract(url=article_url)
    tweet_embed_count = len(article.tweets)
    return tweet_embed_count

# %%
def count_tweet_embed(article_url):
    tweet_info = count_tweets(article_url)
    return tweet_info[1]

# %%
def count_tweet_refs(article_url):
    tweet_info = count_tweets(article_url)
    return tweet_info[0]

# %%
# calculate recall: true positives / true positives + false negatives 
# calculate precision: true positives / total positives 

def calculate_recall_and_precision(gold_labels, given_labels):
    true_pos = 0
    false_neg = 0
    total_pos = 0
    for label_index in range(len(gold_labels)):
        if given_labels[label_index]:
            total_pos += 1
            if gold_labels[label_index]:
                true_pos += 1
        else:
            if gold_labels[label_index]:
                false_neg += 1
    recall = true_pos / (true_pos + false_neg)
    precision = true_pos / total_pos
    print('Recall: ' , recall)
    print('Precision: ', precision)
    return recall, precision

# %%
import pandas as pd
# import csv file with the urls for each article with labeled amount of tweets per article 
# into a dataframe

article_csv_url = 'tweet_embed_data.csv'
article_df = pd.read_csv(article_csv_url)

# %%
def generate_tweet_counts(article_df):
    article_df['has_tweets'] = article_df.apply(lambda row: row['tweet_count'] > 0, axis = 1)
    article_df['calc_embedded'] = article_df.apply(lambda row: count_tweet_embed(row['url']), axis = 1)
    article_df['goose3_tweet_embeds'] = article_df.apply(lambda row: count_tweets_goose(row['url']), axis = 1)
    article_df['calc_tweet_refs'] = article_df.apply(lambda row: count_tweet_refs(row['url']), axis = 1)
    article_df['calc_has_tweets'] = article_df.apply(lambda row: row['calc_embedded'] > 0 or 
                                                     row['calc_tweet_refs'] > 0, axis = 1)
    
    # calculate and print precision and recall
    recall, precision = calculate_recall_and_precision(article_df['has_tweets'], article_df['calc_has_tweets'])
    return article_df

# %%
generate_tweet_counts(article_df)
# Out:
# Recall:  0.9166666666666666
# Precision:  0.868421052631579
#                                                   url  tweet_count  \
# 0   https://www.theguardian.com/world/2021/may/13/...            2
# 1   https://www.usatoday.com/story/sports/mlb/colu...            2
# 2   https://www.cnn.com/2021/05/23/europe/belarus-...            1
# 3   https://www.foxnews.com/opinion/biden-southern...            1
# 4   https://newrepublic.com/article/161084/republi...            1
# 5   https://www.cnn.com/2021/05/17/investing/bitco...            6
# 6   https://www.breitbart.com/economy/2021/03/03/w...            4
# 7   https://www.csmonitor.com/World/Asia-South-Cen...            1
# 8   https://www.vice.com/en/article/wx8wm5/arkansa...            1
# 9   https://www.staradvertiser.com/2021/05/17/brea...            1
# 10  https://www.techradar.com/news/lord-of-the-rin...            1
# 11  https://www.npr.org/2021/05/04/993604289/man-w...            1
# 12      https://www.alternet.org/2021/05/voting-laws/            3
# 13  https://eurweb.com/2021/02/25/cerise-castle-pu...            2
# 14  https://www.cbsnews.com/news/alexei-navalny-ru...            2
# 15  https://www.cbsnews.com/news/rand-paul-suspici...            1
# 16  https://www.cbsnews.com/news/covid-19-vaccine-...            1
# 17  https://www.npr.org/2021/05/25/1000129271/marj...            4
# 18  https://www.npr.org/2021/05/20/998795586/orteg...            2
# 19  https://www.msnbc.com/opinion/saying-israel-gu...            1
# 20  https://boston.cbslocal.com/2021/05/26/boston-...            2
# 21  https://www.npr.org/2021/05/24/999790233/offic...            1
# 22  https://www.msnbc.com/opinion/texas-new-aborti...            1
# 23  https://www.cnn.com/us/live-news/san-jose-ca-s...            4
# 24  https://www.cnn.com/2021/05/25/politics/marjor...            2
# 25  https://www.cbsnews.com/news/texas-defund-poli...            2
# 26  https://edition.cnn.com/2021/05/12/football/mo...            6
# 27     https://www.bbc.com/news/world-europe-57250285            1
# 28  https://www.foxbusiness.com/lifestyle/gas-pric...            4
# 29  https://www.cnbc.com/2021/05/06/desantis-signs...            3
# 30  https://www.foxnews.com/politics/black-lives-m...            3
# 31  https://www.foxnews.com/us/new-jersey-house-pa...            3
# 32  https://www.foxnews.com/us/fox-news-spots-migr...            1
# 33  https://www.foxnews.com/us/us-seeing-wave-of-t...            2
# 34  https://www.npr.org/2021/05/21/999020140/its-n...            1
# 35  https://economictimes.indiatimes.com/news/indi...            1
# 36  https://www.azcentral.com/story/news/local/ari...            0
# 37  https://www.foxnews.com/media/dueling-narrativ...            0
# 38  https://www.arkansasonline.com/news/2021/may/1...            0
# 39  https://www.cnn.com/2021/05/26/world/antarctic...            0
# 40  https://www.cnn.com/2021/05/24/entertainment/k...            0
# 41  https://www.msnbc.com/opinion/what-israel-call...            0
# 42  https://www.msnbc.com/opinion/military-police-...            0
# 43  https://www.msnbc.com/opinion/republicans-say-...            0
# 44  https://www.thedailybeast.com/the-matt-gaetz-a...            0
# 45  https://thehill.com/homenews/media/552420-poll...            0
# 46  https://www.npr.org/2021/05/25/999791732/mask-...            0
# 47  https://www.npr.org/sections/health-shots/2021...            0
#
#     has_tweets  calc_embedded  goose3_tweet_embeds  calc_tweet_refs  \
# 0         True              0                    0                4
# 1         True              2                    0                5
# 2         True              0                    0                4
# 3         True              1                    0                0
# 4         True              0                    1                2
# 5         True              4                    1               20
# 6         True              0                    3                2
# 7         True              0                    0                1
# 8         True              0                    0                3
# 9         True              0                    0                0
# 10        True              1                    4                1
# 11        True              1                    0                1
# 12        True              6                    0                3
# 13        True              3                    0                0
# 14        True              0                    2                0
# 15        True              0                    1                6
# 16        True              0                    0                2
# 17        True              5                    0                3
# 18        True              2                    0                4
# 19        True              3                    0                4
# 20        True              0                    1                1
# 21        True              2                    0                2
# 22        True              0                    1                2
# 23        True              0                    0                7
# 24        True              1                    0                7
# 25        True              1                    1                8
# 26        True              0                    5               16
# 27        True              0                    1                7
# 28        True              1                    0                6
# 29        True              0                    0                4
# 30        True              0                    0                8
# 31        True              1                    0                2
# 32        True              0                    0                0
# 33        True              2                    0                0
# 34        True              1                    0                0
# 35        True              0                    0                1
# 36       False              1                    0                3
# 37       False              0                    0                2
# 38       False              0                    0                0
# 39       False              0                    0                0
# 40       False              0                    0                0
# 41       False              6                    0                0
# 42       False              0                    0                0
# 43       False              0                    1                0
# 44       False              0                    0                2
# 45       False              0                    0                2
# 46       False              0                    0                0
# 47       False              0                    0                0
#
#     calc_has_tweets
# 0              True
# 1              True
# 2              True
# 3              True
# 4              True
# 5              True
# 6              True
# 7              True
# 8              True
# 9             False
# 10             True
# 11             True
# 12             True
# 13             True
# 14            False
# 15             True
# 16             True
# 17             True
# 18             True
# 19             True
# 20             True
# 21             True
# 22             True
# 23             True
# 24             True
# 25             True
# 26             True
# 27             True
# 28             True
# 29             True
# 30             True
# 31             True
# 32            False
# 33             True
# 34             True
# 35             True
# 36             True
# 37             True
# 38            False
# 39            False
# 40            False
# 41             True
# 42            False
# 43            False
# 44             True
# 45             True
# 46            False
# 47            False
